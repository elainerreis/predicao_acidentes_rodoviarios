# %% [markdown]
# # 04 - Comparação Final
#
# Síntese e discussão dos resultados.

# %% [markdown]
# ## Conclusão
#
# O XGBoost apresentou melhor desempenho geral em relação à regressão logística,
# especialmente nas métricas relacionadas à classe grave.
